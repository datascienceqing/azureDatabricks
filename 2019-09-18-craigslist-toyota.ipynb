portland.craigslist.org/mlt/cto/d/portland-2010-toyota-highlander-hybrid/6969381540.html</td><td>4wd</td></tr><tr><td>$29500</td><td>2013 Toyota Tacoma supercharged from factory</td><td>https://portland.craigslist.org/clk/cto/d/raymond-2013-toyota-tacoma-supercharged/6969550247.html</td><td>gas</td></tr><tr><td>$700</td><td>2002 Toyota Corolla LE</td><td>https://portland.craigslist.org/clk/cto/d/ridgefield-2002-toyota-corolla-le/6969545856.html</td><td>gas</td></tr><tr><td>$9000</td><td>Low Mileage - 2010 Toyota Corolla XLE</td><td>https://portland.craigslist.org/wsc/cto/d/portland-low-mileage-toyota-corolla-xle/6969528169.html</td><td>fwd</td></tr><tr><td>$2550</td><td>83 Toyota pickup</td><td>https://portland.craigslist.org/nco/cto/d/longview-83-toyota-pickup/6969528923.html</td><td>gas</td></tr><tr><td>$1000</td><td>'96 TOYOTA CAMRY LE</td><td>https://portland.craigslist.org/nco/cto/d/warrenton-96-toyota-camry-le/6969538701.html</td><td>fwd</td></tr><tr><td>$17999</td><td>2014 toyota tundra sr5 4x4, 4.6 liter</td><td>https://portland.craigslist.org/mlt/cto/d/gresham-2014-toyota-tundra-sr5-4x4-46/6969539199.html</td><td>4wd</td></tr><tr><td>$3100</td><td>2003 toyota corolla</td><td>htt ...

# %%
table_name = "car_deals"
df.write.mode('OverWrite').format('parquet').saveAsTable(table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.functions import avg, col, udf,desc

@udf('integer')
def convert_value(value):
  try:
    return int(value.replace('$',''))
  except ValueError:
    return None
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">5</span><span class="ansired">]: </span>603</div>

# %%
#delete the duplicates

df=df.distinct()
df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">6</span><span class="ansired">]: </span>493</div>

# %%
#in case there are multiple prices for one car, let's get the average price for one car
one_car_avg_price= df\
  .select(convert_value('price').alias('price'),'Url')\
  .groupBy('Url')\
  .agg(avg('price').cast('integer'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
one_car_avg_price.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+----------+
#                  Url|avg(price)|
# +--------------------+----------+
# https://portland....|   14995.0|
# https://portland....|    4500.0|
# https://portland....|    6800.0|
# https://portland....|    5800.0|
# https://portland....|    5250.0|
# +--------------------+----------+
# only showing top 5 rows
#
# </div>

# %%
#average price of all cars
display(
  one_car_avg_price.select('avg(price)').agg(avg('avg(price)').cast('integer'))
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CAST(avg(avg(price)) AS INT)</th></tr></thead><tbody><tr><td>13163</td></tr></tbody></table></div>

# %%
import re

#extract the year information from Url
@udf('integer')
def get_year(value):
  try:
    year_search=re.search('-(\d+)-toyota-',value,re.IGNORECASE)
    if year_search:
      return int(year_search.group(1))
  except ValueError:
    return None
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Average price by year
display(
  df\
    .select(get_year('Url').alias('year'), convert_value('price').alias('price'),)\
    .where(col('year')>=1950 )\
    .groupBy('year')\
    .agg(avg('price').cast('integer'))\
    .sort('year')
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>year</th><th>CAST(avg(price) AS INT)</th></tr></thead><tbody><tr><td>1967</td><td>22000</td></tr><tr><td>1977</td><td>750</td></tr><tr><td>1983</td><td>22500</td></tr><tr><td>1985</td><td>3175</td></tr><tr><td>1987</td><td>1000</td></tr><tr><td>1990</td><td>4300</td></tr><tr><td>1991</td><td>3995</td></tr><tr><td>1993</td><td>4200</td></tr><tr><td>1994</td><td>9000</td></tr><tr><td>1995</td><td>2100</td></tr><tr><td>1996</td><td>2449</td></tr><tr><td>1997</td><td>3683</td></tr><tr
r><tr><td>198000</td><td>3750</td></tr><tr><td>19992</td><td>18300</td></tr><tr><td>26990</td><td>32400</td></tr><tr><td>129704</td><td>15995</td></tr><tr><td>126000</td><td>6500</td></tr><tr><td>195380</td><td>11382</td></tr><tr><td>279956</td><td>4288</td></tr><tr><td>120000</td><td>27200</td></tr><tr><td>31745</td><td>36988</td></tr><tr><td>96428</td><td>19991</td></tr><tr><td>115004</td><td>14991</td></tr><tr><td>137893</td><td>26900</td></tr><tr><td>232926</td><td>3250</td></tr><tr><td>170048</td><td>5395</td></tr><tr><td>145336</td><td>2600</td></tr><tr><td>32298</td><td>30488</td></tr><tr><td>119223</td><td>8950</td></tr><tr><td>205000</td><td>3200</td></tr><tr><td>68303</td><td>27995</td></tr><tr><td>126454</td><td>17990</td></tr><tr><td>154609</td><td>13995</td></tr><tr><td>156037</td><td>8950</td></tr><tr><td>52981</td><td>37991</td></tr><tr><td>108415</td><td>19990</td></tr><tr><td>248353</td><td>3995</td></tr><tr><td>12148</td><td>35310</td></tr><tr><td>106807</td><td>15995</td></tr><tr><td>62000</td><td>9999</td></tr><tr><td>143842</td><td>16995</td></tr><tr><td>160000</td><td>4400</td></tr><tr><td>180000</td><td>1000</td></tr><tr><td>186774</td><td>13991</td></tr><tr><td>56075</td><td>9995</td></tr><tr><td>108000</td><td>12499</td></tr><tr><td>87000</td><td>1600</td></tr><tr><td>36001</td><td>13400</td></tr><tr><td>108415</td><td>18990</td></tr><tr><td>125202</td><td>14950</td></tr><tr><td>137893</td><td>27900</td></tr><tr><td>70172</td><td>32979</td></tr><tr><td>138122</td><td>7495</td></tr><tr><td>81495</td><td>29990</td></tr><tr><td>242671</td><td>5991</td></tr><tr><td>283000</td><td>1000</td></tr><tr><td>92461</td><td>14991</td></tr><tr><td>69288</td><td>16991</td></tr><tr><td>66785</td><td>16499</td></tr><tr><td>43138</td><td>24995</td></tr><tr><td>13089</td><td>32991</td></tr><tr><td>30634</td><td>20991</td></tr><tr><td>107106</td><td>16999</td></tr><tr><td>121650</td><td>27990</td></tr><tr><td>23282</td><td>34995</td></tr><tr><td>30634</td><td>20991</td></tr><tr><td>140095</td><td>null</td></tr><tr ...

# %%
#let's dump to pandas to calculate the correlation
pandas_df= df\
    .select(get_odo('odometer').alias('odometer'), convert_value('price').alias('price'),)\
    .where(col('odometer').isNotNull() & (col('odometer') >=1000))\
    .toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pandas_df.head()
# Out:
# <div style="max-width:1500px;overflow:auto;">
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>odometer</th>
#       <th>price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>140534</td>
#       <td>16995.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>13666</td>
#       <td>31881.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>291177</td>
#       <td>11995.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>232926</td>
#       <td>3250.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>156037</td>
#       <td>8950.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pandas_df.corr(method='pearson')
# Out:
# <div style="max-width:1500px;overflow:auto;">
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>odometer</th>
#       <th>price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>odometer</th>
#       <td>1.000000</td>
#       <td>-0.727035</td>
#     </tr>
#     <tr>
#       <th>price</th>
#       <td>-0.727035</td>
#       <td>1.000000</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pandas_df_ = df\
    .select(get_year('Url').alias('year'), convert_value('price').alias('price'),)\
    .where(col('year')>=1950 )\
    .groupBy('year')\
    .agg(avg('price').cast('integer'))\
    .toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pandas_df_.corr(method='pearson')
# Out:
# <div style="max-width:1500px;overflow:auto;">
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>year</th>
#       <th>CAST(avg(price) AS INT)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>year</th>
#       <td>1.000000</td>
#       <td>0.508624</td>
#     </tr>
#     <tr>
#       <th>CAST(avg(price) AS INT)</th>
#       <td>0.508624</td>
#       <td>1.000000</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Based on the analysis of 500 toyota used cars, odometer has stronger correlation to price. 
# In other words, odometer reading is more important for used cars.
